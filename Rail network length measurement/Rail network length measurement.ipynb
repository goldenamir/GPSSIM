# %%
try:
    import geopandas as gpd
except:
    # !pip install geopandas

# %%
shp_file = 'Järnvägsnät_längdmätning.dbf'

# %%
db = gpd.read_file(shp_file)
db.head()
# Out:
#   Bandel  KmFran  MeterFran  KmTill  MeterTill   UNE   Sparnr Spartyp  \
# 0    313     161      146.0     161      295.0  None  106-101    ahsp
# 1    313       0      338.0       0      640.0    E3        3    nhsp
# 2    313     160      107.0     160      185.0     E        2    nhsp
# 3    313     160      107.0     160      265.0  None        1    ahsp
# 4    313     161      531.0     161      890.0    E3        3    nhsp
#
#   Langdmatn   Langd NastaBdl  NastaKm  NastaMeter NastaLgdm PlSignFr  \
# 0   cst-rgn  148.76     None      NaN         NaN      None     Avky
# 1   avky-rv  302.05     None      NaN         NaN      None     Avky
# 2   cst-rgn   78.45     None      NaN         NaN      None     Avky
# 3   cst-rgn  157.68     None      NaN         NaN      None     Avky
# 4  cst-fv/n  359.14     None      NaN         NaN      None     Avky
#
#   NodSignFr PlSignTi NodSignTi    Skapad  \
# 0       106     Avky       101  20181104
# 1       106     Avky     gr-03  20181104
# ...

# %%
db.shape
# Out:
# (39614, 20)
