# %%
try:
    import geopandas as gpd
except:
    # !pip install geopandas

# %%
shp_file = 'Järnvägsnät_med_grundegenskaper.dbf'

# %%
db = gpd.read_file(shp_file)
db.head()
# Out:
#   Bandelnr             Bandelnamn Straknr                     Straknamn  \
# 0      313  Avesta/Krylbo-(Frövi)    None                          None
# 1      313  Avesta/Krylbo-(Frövi)      09  Godsstråket genom Bergslagen
# 2      306   Borlänge-(Repbäcken)    None                          None
# 3      323       Falun-(Borlänge)    None                          None
# 4      422    (Katrineholm)-(Åby)      02               Södra Stambanan
#
#   Status TRV_spar Plats ForbLinje PlatsForb InfraForv1  \
# 0  Öppen  stomjvg  Avky      None      Avky        TRV
# 1  Öppen  stomjvg  Avky      None      Avky        TRV
# 2  Öppen  stomjvg   Blg      None       Blg        TRV
# 3  Öppen  övr.jvg   Fln      None       Fln        TRV
# 4  Öppen  stomjvg  None   Stö-Smt   Stö-Smt        TRV
#
#                          ...                         Brotyp  TENkat  TENklass  \
# 0                        ...                           None    XV-M  Icke-TEN
# ...

# %%
db.shape
# Out:
# (52864, 43)

# %%
db.geometry.head()
# Out:
# 0    LINESTRING Z (567444.0000000002 6666888 -99999...
# 1    LINESTRING Z (567705.0000000002 6665935 -99999...
# 2    LINESTRING Z (522968.0000000002 6704434 -99999...
# 3    LINESTRING Z (534616 6717802 -99999, 534635 67...
# 4    LINESTRING Z (569043.0000000002 6529272 -99999...
# Name: geometry, dtype: object
