# %%
try:
    import geopandas as gpd
except:
    # !pip install geopandas

# %%
shp_file = 'Järnvägsnät_bandel_aggregat.dbf'

# %%
db = gpd.read_file(shp_file)
db.head()
# Out:
#   Bandel Bandel_t Plats_fran Plats_till Strak_kod Strak_text Langdmatn  \
# 0    002     None       None       None      None       None   cst-trg
# 1    002     None       None       None      None       None   cst-rgn
# 2    002     None       None       None      None       None     cst-g
# 3    003     None       None       None      None       None   söd-nbr
# 4    003     None       None       None      None       None   oxd-vsg
#
#   Km_start  Km_slut                                           geometry
# 0  178+321  178+490  LINESTRING (567856 6498674, 567966 6498670, 56...
# 1   29+197   30+754  (LINESTRING (663096 6607482, 663084 6607528, 6...
# 2  202+667  203+647  (LINESTRING (503188 6546446, 503164 6546432), ...
# 3   68+117   87+913  (LINESTRING (580740 6585419, 580706 6585429, 5...
# 4  108+176  110+170  (LINESTRING (581244 6584878, 581098 6585022, 5...

# %%
db.shape
# Out:
# (496, 10)

# %%
db
# Out:
#     Bandel                                  Bandel_t  \
# 0      002                                      None
# 1      002                                      None
# 2      002                                      None
# 3      003                                      None
# 4      003                                      None
# 5      003                                      None
# 6      004                                      None
# 7      004                                      None
# 8      005                                      None
# 9      006                                      None
# 10     006                                      None
# 11     007                                      None
# 12     008                                      None
# 13     009                                      None
# 14     009                                      None
# 15     010                                      None
# 16     111                  (Peuravaara)-Riksgränsen
# ...

# %%
db.columns
# Out:
# Index(['Bandel', 'Bandel_t', 'Plats_fran', 'Plats_till', 'Strak_kod',
#        'Strak_text', 'Langdmatn', 'Km_start', 'Km_slut', 'geometry'],
#       dtype='object')

# %% [markdown]
# # Converting to Excel file

# %%
# It is necessary to convert it to pandas file first
# then for the conversion, I drop the last column (geometry) and specify the column names for the new df
import pandas as pd
try:
    import xlsxwriter
except:
    # !pip install xlsxwriter
df1 = pd.DataFrame(db.iloc[:,:-1].values, columns = list(db.columns.values)[:-1] )

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RailwayNetworkBandelAggregate.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df1.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
